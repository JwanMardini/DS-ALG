# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import style

# %%
# Data
x_values = [1000, 5000, 10000, 50000, 100000, 500000, 1000000]
y_values = [2.6, 22.0, 114.9, 2251, 10330, 239387, 1964479.7]

# Create the chart
plt.plot(x_values, y_values, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Your Chart Title')

# Add ticks to both axes
plt.xticks(x_values)
plt.yticks(y_values)

# Show the chart
plt.show()

# %%
time_data = {"facebook": 120, "youtube": 60, "instagram": 90, "whatsapp": 30}
social_media = list(time_data.keys())
time_spent = list(time_data.values())

# %%
style.use('ggplot')
plt.figure(figsize=(5,5))
color = ['red', 'blue', 'green', 'yellow']
plt.bar(social_media, time_spent, color=color, width=0.5)
plt.xlabel("Social Media")
plt.ylabel("Time Spent")
plt.title("Time Spent on Social Media")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jwan9\OneDrive\Skrivbord\DS-ALG\Untitled-1.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(5,5))
#       <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> color = ['red', 'blue', 'green', 'yellow']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> plt.bar(social_media, time_spent, color=color, width=0.5)
#       <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> plt.xlabel("Social Media")
# ...

# %%
insertionSortIterative = ()
insertionSortRecursive = ()
quickSortRandomPivotIterative = ()
quickSortRandomPivotRecursive = ()
quickSortMedianPivotIterative = ()
quickSortMedianPivotRecursive = ()
quickSortFirstElementPivotIterative = ()
quickSortFirstElementPivotRecursive = ()
input = (1000, 5000, 10000, 50000, 100000, 500000, 1000000)

# %%
xpos =  np.arange(len(input))

# %%
style.use('ggplot')
plt.figure(figsize=(10,10))
barwidth = 0.2
plt.bar(xpos, insertionSortIterative, color="royalblue", width=barwidth, label="Insertion Sort Iterative")
#plt.bar(xpos+0.2, yt, color="tomato", width=barwidth, label="YT")
#plt.bar(xpos+0.4, insta, color="gold", width=barwidth, label="Insta")
#plt.bar(xpos+0.6, whatsapp, color="green", width=barwidth, label="Whatsapp")
plt.xticks(xpos+0.3, (1000, 5000, 10000, 50000, 100000, 500000, 1000000))
plt.xlabel("Days")
plt.ylabel("Time Spent")
plt.title("Time Spent on Social Media")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\jwan9\OneDrive\Skrivbord\DS-ALG\Untitled-1.ipynb Cell 8 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(10,10))
#       <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> barwidth = 0.2
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> plt.bar(xpos, insertionSortIterative, color="royalblue", width=barwidth, label="Insertion Sort Iterative")
#       <a href='vscode-notebook-cell:/c%3A/Users/jwan9/OneDrive/Skrivbord/DS-ALG/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> #plt.bar(xpos+0.2, yt, color="tomato", width=barwidth, label="YT")
# ...
